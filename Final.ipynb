# %%
import pandas as pd
import requests
import json
from sodapy import Socrata

# %%
client = Socrata("data.cityofnewyork.us","" ) #App Token Key 

#2016-2017 CTE Data

#2017-2018 CTE Data

#2018-2019 CTE Data

#2019-2020 CTE Data
results = client.get("gyjk-fbss",) #API Get Request
df = pd.DataFrame.from_records(results)
df.to_csv("cte_data_2019_2020.csv", index=False)
cte_2019_2020 = pd.read_csv("cte_data_2019_2020.csv")
cte_2019_2020.head()
# Out:
#       dbn                                        school_name  \
# 0  01M448                University Neighborhood High School
# 1  02M135  The Urban Assembly School for Emergency Manage...
# 2  02M139  Stephen T. Mather Building Arts & Craftsmanshi...
# 3  02M280     Manhattan Early College School for Advertising
# 4  02M282                       Urban Assembly Maker Academy
#
#    cte_designated_high_school  program_cip_code  \
# 0                       False            520701
# 1                        True            439999
# 2                        True            469999
# 3                        True            110899
# 4                        True            110201
#
#                                       program_name  \
# 0         Entrepreneurship/Entrepreneurial Studies
# 1          Security and Protective Services, Other
# 2                       Construction Trades, Other
# 3  Computer Software and Media Applications, Other
# ...
